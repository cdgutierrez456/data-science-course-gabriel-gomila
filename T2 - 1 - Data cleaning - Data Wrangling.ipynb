# %% [markdown]
# # Data Wrangling - La cirugia de los datos
#
# El '''data wrangling''', a veces denominada '''data munging''', es el proceso de transformar y mapear datos de un dataset raw (en bruto) en otro formato con la intension de hacerlo mas apropiado y valioso para una variedad de propositos posteriores, como el analisis. Un '''data wrangler''' es una persona que realiza estas operaciones de transformacion.
#
# Esto puede incluir munging, visualizacion de datos, agregacion de datos, entrenamiento de un modelo estadistico, asi como muchos otros usos potenciales. La oscilacion de datos como proceso generalmente sigue un conjunto de pasos generales que comienzan extrayendo los datos en forma cruda del origen de datos, dividiendo los datos en bruto usando algoritmos (ej. Clasificacion) o analizando los datos en estructuras de datos predefinidas, y finalmente depositando el contenido resultante en un sistema de almacenamiento (o silo) para su uso futuro.

# %%
import pandas as pd

# %%
data = pd.read_csv('../resources/datasets/customer-churn-model/Customer Churn Model.txt')

# %%
data.head()
# Out:
#   State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 0    KS             128        415  382-4657         no        yes
# 1    OH             107        415  371-7191         no        yes
# 2    NJ             137        415  358-1921         no         no
# 3    OH              84        408  375-9999        yes         no
# 4    OK              75        415  330-6626        yes         no
#
#    VMail Message  Day Mins  Day Calls  Day Charge  ...  Eve Calls  Eve Charge  \
# 0             25     265.1        110       45.07  ...         99       16.78
# 1             26     161.6        123       27.47  ...        103       16.62
# 2              0     243.4        114       41.38  ...        110       10.30
# 3              0     299.4         71       50.90  ...         88        5.26
# 4              0     166.7        113       28.34  ...        122       12.61
#
#    Night Mins  Night Calls  Night Charge  Intl Mins  Intl Calls  Intl Charge  \
# ...

# %% [markdown]
# ## Crear un subconjunto de datos

# %%
account_length = data['Account Length']

# %%
account_length.head()
# Out:
# 0    128
# 1    107
# 2    137
# 3     84
# 4     75
# Name: Account Length, dtype: int64

# %%
type(account_length)
# Out:
# pandas.Series

# %%
subset = data[['Account Length', 'Phone', 'Eve Charge', 'Day Calls']]

# %%
subset.head()
# Out:
#    Account Length     Phone  Eve Charge  Day Calls
# 0             128  382-4657       16.78        110
# 1             107  371-7191       16.62        123
# 2             137  358-1921       10.30        114
# 3              84  375-9999        5.26         71
# 4              75  330-6626       12.61        113

# %%
desired_columns = ['Account Length', 'Phone', 'Eve Charge', 'Day Calls']
subset = data[desired_columns]
subset.head()
# Out:
#    Account Length     Phone  Eve Charge  Day Calls
# 0             128  382-4657       16.78        110
# 1             107  371-7191       16.62        123
# 2             137  358-1921       10.30        114
# 3              84  375-9999        5.26         71
# 4              75  330-6626       12.61        113

# %%
desired_columns = ['Account Length', 'VMail Message', 'Day Calls']
desired_columns
# Out:
# ['Account Length', 'VMail Message', 'Day Calls']

# %%
all_columns_list = data.columns.values.tolist()
all_columns_list
# Out:
# ['State',
#  'Account Length',
#  'Area Code',
#  'Phone',
#  "Int'l Plan",
#  'VMail Plan',
#  'VMail Message',
#  'Day Mins',
#  'Day Calls',
#  'Day Charge',
#  'Eve Mins',
#  'Eve Calls',
#  'Eve Charge',
#  'Night Mins',
#  'Night Calls',
#  'Night Charge',
#  'Intl Mins',
#  'Intl Calls',
#  'Intl Charge',
#  'CustServ Calls',
#  'Churn?']

# %%
sublist = [x for x in all_columns_list if x not in desired_columns]
sublist
# Out:
# ['State',
#  'Area Code',
#  'Phone',
#  "Int'l Plan",
#  'VMail Plan',
#  'Day Mins',
#  'Day Charge',
#  'Eve Mins',
#  'Eve Calls',
#  'Eve Charge',
#  'Night Mins',
#  'Night Calls',
#  'Night Charge',
#  'Intl Mins',
#  'Intl Calls',
#  'Intl Charge',
#  'CustServ Calls',
#  'Churn?']

# %%
subset = data[sublist]
subset.head()
# Out:
#   State  Area Code     Phone Int'l Plan VMail Plan  Day Mins  Day Charge  \
# 0    KS        415  382-4657         no        yes     265.1       45.07
# 1    OH        415  371-7191         no        yes     161.6       27.47
# 2    NJ        415  358-1921         no         no     243.4       41.38
# 3    OH        408  375-9999        yes         no     299.4       50.90
# 4    OK        415  330-6626        yes         no     166.7       28.34
#
#    Eve Mins  Eve Calls  Eve Charge  Night Mins  Night Calls  Night Charge  \
# 0     197.4         99       16.78       244.7           91         11.01
# 1     195.5        103       16.62       254.4          103         11.45
# 2     121.2        110       10.30       162.6          104          7.32
# 3      61.9         88        5.26       196.9           89          8.86
# 4     148.3        122       12.61       186.9          121          8.41
#
#    Intl Mins  Intl Calls  Intl Charge  CustServ Calls  Churn?
# ...

# %%
data[0:24]
# Out:
#    State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 0     KS             128        415  382-4657         no        yes
# 1     OH             107        415  371-7191         no        yes
# 2     NJ             137        415  358-1921         no         no
# 3     OH              84        408  375-9999        yes         no
# 4     OK              75        415  330-6626        yes         no
# 5     AL             118        510  391-8027        yes         no
# 6     MA             121        510  355-9993         no        yes
# 7     MO             147        415  329-9001        yes         no
# 8     LA             117        408  335-4719         no         no
# 9     WV             141        415  330-8173        yes        yes
# 10    IN              65        415  329-6603         no         no
# 11    RI              74        415  344-9403         no         no
# 12    IA             168        408  363-1107         no         no
# ...

# %%
data[:8]
# Out:
#   State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 0    KS             128        415  382-4657         no        yes
# 1    OH             107        415  371-7191         no        yes
# 2    NJ             137        415  358-1921         no         no
# 3    OH              84        408  375-9999        yes         no
# 4    OK              75        415  330-6626        yes         no
# 5    AL             118        510  391-8027        yes         no
# 6    MA             121        510  355-9993         no        yes
# 7    MO             147        415  329-9001        yes         no
#
#    VMail Message  Day Mins  Day Calls  Day Charge  ...  Eve Calls  Eve Charge  \
# 0             25     265.1        110       45.07  ...         99       16.78
# 1             26     161.6        123       27.47  ...        103       16.62
# 2              0     243.4        114       41.38  ...        110       10.30
# ...

# %%
# Usuarios con Tottal Mins > 500
data1 = data[data['Day Mins']>300]
data1.shape
# Out:
# (43, 21)

# %%
# Usuarios de New York (State = 'NY')
data2 = data[data['State']=='NY']
data2.shape
# Out:
# (83, 21)

# %%
# Operator AND -> &
data3 = data[(data['Day Mins'] > 300) & (data['State']=='NY')]
data3.shape
# Out:
# (2, 21)

# %%
# Operator OR -> |
data4 = data[(data['Day Mins']>300) | (data['State']=='NY')]
data4.shape
# Out:
# (124, 21)

# %%
data5 = data[data['Night Calls'] > data['Day Calls']]
data5.shape
# Out:
# (1626, 21)

# %%
# Minutos de dia, de noche y longitud de la cuenta de los primeros 50 individuos
desired_columns = ['Day Mins', 'Night Mins', 'Account Length']
subset_first_50 = data[desired_columns][:50]
subset_first_50.shape
# Out:
# (50, 3)

# %%
# Primeras 10 filas, columnas de la 3 a la 6
data.iloc[0:10, 3:6]
# Out:
#       Phone Int'l Plan VMail Plan
# 0  382-4657         no        yes
# 1  371-7191         no        yes
# 2  358-1921         no         no
# 3  375-9999        yes         no
# 4  330-6626        yes         no
# 5  391-8027        yes         no
# 6  355-9993         no        yes
# 7  329-9001        yes         no
# 8  335-4719         no         no
# 9  330-8173        yes        yes

# %%
# Todas las filas para las columnas entre la 3 y la 6
data.iloc[:, 3:6]

#Todas las columnas para las filas de la 1 a la 10
data.iloc[:10,:]
# Out:
#   State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 0    KS             128        415  382-4657         no        yes
# 1    OH             107        415  371-7191         no        yes
# 2    NJ             137        415  358-1921         no         no
# 3    OH              84        408  375-9999        yes         no
# 4    OK              75        415  330-6626        yes         no
# 5    AL             118        510  391-8027        yes         no
# 6    MA             121        510  355-9993         no        yes
# 7    MO             147        415  329-9001        yes         no
# 8    LA             117        408  335-4719         no         no
# 9    WV             141        415  330-8173        yes        yes
#
#    VMail Message  Day Mins  Day Calls  Day Charge  ...  Eve Calls  Eve Charge  \
# 0             25     265.1        110       45.07  ...         99       16.78
# ...

# %%
# Seleccionando columnas por indice para filas de la 1 a la 10
data.iloc[:10, [2,5,7]]
# Out:
#    Area Code VMail Plan  Day Mins
# 0        415        yes     265.1
# 1        415        yes     161.6
# 2        415         no     243.4
# 3        408         no     299.4
# 4        415         no     166.7
# 5        510         no     223.4
# 6        510        yes     218.2
# 7        415         no     157.0
# 8        408         no     184.5
# 9        415        yes     258.6

# %%
data.iloc[[1,5,8,36], [2,5,7]]
# Out:
#     Area Code VMail Plan  Day Mins
# 1         415        yes     161.6
# 5         510         no     223.4
# 8         408         no     184.5
# 36        408        yes     146.3

# %%
data.loc[[1,5,8,36], ['Area Code', 'VMail Plan', 'Day Mins']]
# Out:
#     Area Code VMail Plan  Day Mins
# 1         415        yes     161.6
# 5         510         no     223.4
# 8         408         no     184.5
# 36        408        yes     146.3

# %%
data['Total Mins'] = data['Day Mins'] + data['Night Mins'] + data['Eve Mins']

# %%
data['Total Mins'].head()
# Out:
# 0    707.2
# 1    611.5
# 2    527.2
# 3    558.2
# 4    501.9
# Name: Total Mins, dtype: float64

# %%
data['Total Calls'] = data['Day Calls'] + data['Night Calls'] + data['Eve Calls']

# %%
data['Total Calls'].head()
# Out:
# 0    300
# 1    329
# 2    328
# 3    248
# 4    356
# Name: Total Calls, dtype: int64

# %%
data.shape
# Out:
# (3333, 23)

# %%
data.head()
# Out:
#   State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 0    KS             128        415  382-4657         no        yes
# 1    OH             107        415  371-7191         no        yes
# 2    NJ             137        415  358-1921         no         no
# 3    OH              84        408  375-9999        yes         no
# 4    OK              75        415  330-6626        yes         no
#
#    VMail Message  Day Mins  Day Calls  Day Charge  ...  Night Mins  \
# 0             25     265.1        110       45.07  ...       244.7
# 1             26     161.6        123       27.47  ...       254.4
# 2              0     243.4        114       41.38  ...       162.6
# 3              0     299.4         71       50.90  ...       196.9
# 4              0     166.7        113       28.34  ...       186.9
#
#    Night Calls  Night Charge  Intl Mins  Intl Calls  Intl Charge  \
# 0           91         11.01       10.0           3         2.70
# ...
